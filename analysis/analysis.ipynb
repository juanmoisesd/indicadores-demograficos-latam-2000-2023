# %% [markdown]
# # Indicadores Demográficos Derivados para América Latina (2000-2023): Índice de Envejecimiento, Razones de Dependencia e Índice de Bono Demográfico por País
#
# **DOI:** [10.5281/zenodo.18900862](https://doi.org/10.5281/zenodo.18900862)
# **Author:** de la Serna Tuya, Juan Moisés · ORCID: 0000-0002-8401-8018
# **License:** CC0 1.0
#
# ---
#
# Abstract (English)
# &nbsp;
# This derived dataset extends the original population dataset by age groups in Latin America (de la Serna, 2026; DOI: 10.5281/zenodo.18891177) by adding five calculated demographic indicators for 11 Latin American countries across four reference years (2000, 2010, 2020, and 2023). No raw data were modified; all variables were computed from the absolute population estimates
#
# **Keywords:** demographic indicators, aging index, dependency ratio, demographic bonus, Latin America, demographic transition, population aging, working-age population, derived dataset, America Latina

# %%
# Install dependencies if needed
# !pip install pandas matplotlib seaborn numpy

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.dpi'] = 120
print('Libraries loaded.')

# %% [markdown]
# ## 1. Load Dataset

# %%
# Download from: https://doi.org/10.5281/zenodo.18900862
# df = pd.read_csv('dataset.csv')

# Synthetic example data
np.random.seed(42)
years = list(range(2000, 2024))
keywords = ['demographic indicators', 'aging index', 'dependency ratio', 'demographic bonus']
df = pd.DataFrame({'year': years,
    **{k.replace(' ','_')[:12]: np.random.normal(50,15,len(years)) for k in keywords}})

print(f'Dataset: Indicadores Demográficos Derivados para América La')
print(f'DOI: 10.5281/zenodo.18900862')
print(f'Shape: {df.shape}')
df.head()

# %% [markdown]
# ## 2. Summary Statistics

# %%
df.describe().round(2)

# %% [markdown]
# ## 3. Temporal Trends

# %%
fig, ax = plt.subplots(figsize=(10,5))
for col in df.columns[1:]:
    ax.plot(df['year'], df[col], marker='o', markersize=3, label=col)
ax.set_title('Indicadores Demográficos Derivados para América Latina ')
ax.set_xlabel('Year')
ax.set_ylabel('Value')
ax.legend(fontsize=8)
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Citation

# %%
print('APA:')
print('de la Serna Tuya, Juan Moisés (2026). Indicadores Demográficos Derivados para América Latina (2000-2023): Ín. Zenodo. https://doi.org/10.5281/zenodo.18900862')
